# %% [markdown]
# ## Plotly and Cufflinks
#
# Plotly is a library that allows you to create interactive plots that you can use in dashboards or websites (you can save them as html files or static images)

# %% [markdown]
# ## Installation
#
# In order for this to work, you'll need to install plotly and cufflinks to call plots directly off of a pandas dataframe. These libraries are not currently through conda but are available through conda but are available through pip. Install the libraries at your command line/terminal using
#
#     pip install plotly
#     pip install cufflinks
# ** NOTE: Make sure you only have one installation of Python on your computer when you do this, otherwise the installation may not work. **

# %%
import pandas as pd
import numpy as np

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 4.3.0

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
# For notebooks
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# For offline use
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# DATA
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.724005  0.235993 -1.023435 -0.497288
# 1  0.225726  1.897929  0.567355  0.374055
# 2  0.106044  1.140123  1.530771  1.628872
# 3 -0.212908 -0.028167 -0.005930  1.090365
# 4  0.423561  1.635246 -0.325689  2.144199

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# ## Using Cufflinks and iplot()
#
# * scatter
# * bar
# * box
# * spread
# * ratio
# * heatmap
# * surface
# * histogram
# * bubble

# %%
df.plot()

# %%
# %matplotlib inline

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="5e1b74ba-a9e3-4606-aa5f-a5588a21d1da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5e1b74ba-a9e3-4606-aa5f-a5588a21d1da")) {
#                     Plotly.newPlot(
#                         '5e1b74ba-a9e3-4606-aa5f-a5588a21d1da',
# ...

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=20)
# Out:
# <div>
#
#
#             <div id="2ce4858e-ea01-46ca-92ed-6e9c8b53e5e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2ce4858e-ea01-46ca-92ed-6e9c8b53e5e1")) {
#                     Plotly.newPlot(
#                         '2ce4858e-ea01-46ca-92ed-6e9c8b53e5e1',
# ...

# %%
df2.iplot(kind='bar',x='Category',y='Values')
# Out:
# <div>
#
#
#             <div id="da6d672b-0c4d-4ca9-b6cd-613f685c422c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("da6d672b-0c4d-4ca9-b6cd-613f685c422c")) {
#                     Plotly.newPlot(
#                         'da6d672b-0c4d-4ca9-b6cd-613f685c422c',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Values", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="119576f3-2cf6-4dde-9d75-1ed69daa1050" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("119576f3-2cf6-4dde-9d75-1ed69daa1050")) {
#                     Plotly.newPlot(
#                         '119576f3-2cf6-4dde-9d75-1ed69daa1050',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [9.52630673018173, -1.8319092075484462, -0.3135972860830857, -3.2454064051644274]}],
# ...

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="16d057fc-3788-4617-9584-1377917e825f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("16d057fc-3788-4617-9584-1377917e825f")) {
#                     Plotly.newPlot(
#                         '16d057fc-3788-4617-9584-1377917e825f',
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="7b18dd80-f398-4526-b96c-eceeaf064eeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7b18dd80-f398-4526-b96c-eceeaf064eeb")) {
#                     Plotly.newPlot(
#                         '7b18dd80-f398-4526-b96c-eceeaf064eeb',
# ...

# %%
df['A'].iplot(kind='hist',bins=50)
# Out:
# <div>
#
#
#             <div id="ab8621f5-9f3f-4c4c-8123-79d1b4e6b9a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ab8621f5-9f3f-4c4c-8123-79d1b4e6b9a0")) {
#                     Plotly.newPlot(
#                         'ab8621f5-9f3f-4c4c-8123-79d1b4e6b9a0',
# ...

# %%
df.iplot(kind='hist',bins=50)
# Out:
# <div>
#
#
#             <div id="28cf0be1-43a3-436c-945c-05d72c4ff78b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("28cf0be1-43a3-436c-945c-05d72c4ff78b")) {
#                     Plotly.newPlot(
#                         '28cf0be1-43a3-436c-945c-05d72c4ff78b',
# ...

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="42009c72-a161-45b6-8988-eddc2cd944a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("42009c72-a161-45b6-8988-eddc2cd944a3")) {
#                     Plotly.newPlot(
#                         '42009c72-a161-45b6-8988-eddc2cd944a3',
# ...

# %%
df.iplot(kind='bubble',x='A',y='B',size='C')
# Out:
# <div>
#
#
#             <div id="3a349b7f-da40-48aa-887b-ece57aa26318" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3a349b7f-da40-48aa-887b-ece57aa26318")) {
#                     Plotly.newPlot(
#                         '3a349b7f-da40-48aa-887b-ece57aa26318',
# ...

# %%
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="91a23ec0-56a3-46f0-bdb5-c923c708fe7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("91a23ec0-56a3-46f0-bdb5-c923c708fe7e")) {
#                     Plotly.newPlot(
#                         '91a23ec0-56a3-46f0-bdb5-c923c708fe7e',
# ...
